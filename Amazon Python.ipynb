# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C://Users//User//Documents//Projects//Data Analysis//Finance//Amazon Sale Report.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9272\1046035979.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C://Users//User//Documents//Projects//Data Analysis//Finance//Amazon Sale Report.csv')

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
print(df.head())
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545  4/30/2022                     Cancelled
# 1      1  171-9198151-1101146  4/30/2022  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  4/30/2022                       Shipped
# 3      3  403-9615377-8133951  4/30/2022                     Cancelled
# 4      4  407-1069790-7240320  4/30/2022                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      128975 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of          index             Order ID       Date                        Status  \
# 0            0  405-8078784-5731545  4/30/2022                     Cancelled
# 1            1  171-9198151-1101146  4/30/2022  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  4/30/2022                       Shipped
# 3            3  403-9615377-8133951  4/30/2022                     Cancelled
# 4            4  407-1069790-7240320  4/30/2022                       Shipped
# ...        ...                  ...        ...                           ...
# 128970  128970  406-6001380-7673107  5/31/2022                       Shipped
# 128971  128971  402-9551604-7544318  5/31/2022                       Shipped
# 128972  128972  407-9547469-3152358  5/31/2022                       Shipped
# 128973  128973  402-6184140-0545956  5/31/2022                       Shipped
# 128974  128974  408-7436540-8728312  5/31/2022                       Shipped
#
# ...

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
# Check unique values in the 'Fulfilment' column
Fulfilment_unique_values = df['Fulfilment'].unique()
print(Fulfilment_unique_values)

# Count of orders Fulfiled by merchants and Amazon
Fulfilment_counts = df['Fulfilment'].value_counts()
print(Fulfilment_counts)
# Out:
# ['Merchant' 'Amazon']
# Fulfilment
# Amazon      89698
# Merchant    39277
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Assuming df is the DataFrame with the fulfillment information
Fulfilment_counts = df['Fulfilment'].value_counts()

# Plotting the bar plot
Fulfilment_counts.plot(kind='bar', color=['blue', 'green'])
plt.title('Fulfilment Comparison: Amazon vs Merchant')
plt.xlabel('Fulfilment Type')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example for 'quantity' distribution
sns.histplot(df['Qty'])
plt.show()

# %%
# Example for 'amount' summary statistics
sns.boxplot(x=df['Amount'])
plt.show()

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Set 'Date' column as the index
df.set_index('Date', inplace=True)

# Display the first few rows of the updated DataFrame
print(df.head())
# Out:
#             index             Order ID                        Status  \
# Date
# 2022-04-30      0  405-8078784-5731545                     Cancelled
# 2022-04-30      1  171-9198151-1101146  Shipped - Delivered to Buyer
# 2022-04-30      2  404-0687676-7273146                       Shipped
# 2022-04-30      3  403-9615377-8133951                     Cancelled
# 2022-04-30      4  407-1069790-7240320                       Shipped
#
#            Fulfilment Sales Channel  ship-service-level    Style  \
# Date
# 2022-04-30   Merchant      Amazon.in           Standard   SET389
# 2022-04-30   Merchant      Amazon.in           Standard  JNE3781
# 2022-04-30     Amazon      Amazon.in          Expedited  JNE3371
# 2022-04-30   Merchant      Amazon.in           Standard    J0341
# 2022-04-30     Amazon      Amazon.in          Expedited  JNE3671
#
#                         SKU       Category Size  ... currency  Amount  \
# Date                                             ...
# ...

# %%
# Plot the time series data
plt.figure(figsize=(15, 6))
plt.plot(df.index, df['Qty'], label='Qty')
plt.title('Time Series Analysis - Qty over Time')
plt.xlabel('Date')
plt.ylabel('Qty')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter plot for Quantity vs Amount
plt.scatter(df['Qty'], df['Amount'])
plt.xlabel('Qty')
plt.ylabel('Amount')
plt.title('Scatter Plot: Qty vs Amount')
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting histogram for Quantity
df['Qty'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.show()

# %%
correlation_matrix = df[['Qty', 'Amount']].corr()

import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix: Quantity vs Amount')
plt.show()

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.head
# Out:
# <bound method NDFrame.head of              index             Order ID                        Status  \
# Date
# 2022-04-30       0  405-8078784-5731545                     Cancelled
# 2022-04-30       1  171-9198151-1101146  Shipped - Delivered to Buyer
# 2022-04-30       2  404-0687676-7273146                       Shipped
# 2022-04-30       3  403-9615377-8133951                     Cancelled
# 2022-04-30       4  407-1069790-7240320                       Shipped
# ...            ...                  ...                           ...
# 2022-05-31  128970  406-6001380-7673107                       Shipped
# 2022-05-31  128971  402-9551604-7544318                       Shipped
# 2022-05-31  128972  407-9547469-3152358                       Shipped
# 2022-05-31  128973  402-6184140-0545956                       Shipped
# 2022-05-31  128974  408-7436540-8728312                       Shipped
#
#            Fulfilment Sales Channel  ship-service-level    Style  \
# Date
# ...

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming df is the DataFrame
b2b_counts = df['B2B'].value_counts()
colors = ['skyblue', 'lightcoral']

plt.figure(figsize=(8, 8))
plt.pie(b2b_counts, labels=b2b_counts.index, autopct='%1.1f%%', colors=colors, startangle=90, wedgeprops=dict(width=0.4))
plt.title('B2B vs B2C Sales Distribution')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is the DataFrame
plt.figure(figsize=(10, 6))
sns.countplot(x='Status', data=df, palette='viridis')
plt.title('Distribution of Order Status')
plt.xlabel('Order Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9272\4206974911.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Status', data=df, palette='viridis')

# %%
df['Status'].value_counts()
# Out:
# Status
# Shipped                          77804
# Shipped - Delivered to Buyer     28769
# Cancelled                        18332
# Shipped - Returned to Seller      1953
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
# Quantity analysis for Ship Service Levels
ship_service_quantity = df.groupby('ship-service-level')['Qty'].sum()

# Plotting a bar chart
ship_service_quantity.plot(kind='bar', figsize=(10, 6), color='skyblue', edgecolor='black')
plt.title('Quantity Analysis by Ship Service Level')
plt.xlabel('Ship Service Level')
plt.ylabel('Total Quantity Shipped')
plt.show()

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Assuming the DataFrame is named df
sales_channel_counts = df['Sales Channel '].value_counts()
labels = sales_channel_counts.index
sizes = sales_channel_counts.values

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title('Distribution of Sales Channels')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming df is the DataFrame with the relevant data
sales_channel_counts = df['Sales Channel '].value_counts()

# Plotting the bar chart
plt.bar(sales_channel_counts.index, sales_channel_counts.values)
plt.xlabel('Sales Channel')
plt.ylabel('Number of Customers')
plt.title('Customer Segmentation by Sales Channel')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is the DataFrame with the relevant data
plt.figure(figsize=(10, 6))

# Create a bar chart using seaborn
sns.countplot(x='Sales Channel ', hue='B2B', data=df)

plt.xlabel('Sales Channel')
plt.ylabel('Number of Customers')
plt.title('Customer Segmentation by Sales Channel and B2B Status')
plt.show()

# %%
# Display basic statistics for the "Amount" column
amount_stats = df['Amount'].describe()

# Calculate total sales
total_sales = df['Amount'].sum()

# Display total sales and basic statistics
print(f'Total Sales: ${total_sales:.2f}')
print('\nBasic Statistics for "Amount" column:')
print(amount_stats)

# Create a histogram to visualize the distribution of total sales
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df['Amount'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Total Sales')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# Total Sales: $78592678.30
#
# Basic Statistics for "Amount" column:
# count    121180.000000
# mean        648.561465
# std         281.211687
# min           0.000000
# 25%         449.000000
# 50%         605.000000
# 75%         788.000000
# max        5584.000000
# Name: Amount, dtype: float64

# %%
# Import necessary libraries
import pandas as pd

# Load dataset (.csv file)
df = pd.read_csv('C://Users//User//Documents//Projects//Data Analysis//Finance//Amazon Sale Report.csv')

# Calculate conversion rate based on Sales Channel
sales_channel_conversion = df.groupby('Sales Channel ')['Courier Status'].value_counts(normalize=True).unstack()

# Calculate conversion rate based on Courier Status
courier_status_conversion = df.groupby('Courier Status')['Sales Channel '].value_counts(normalize=True).unstack()

# Print or visualize the results as needed
print("Conversion Rate based on Sales Channel:")
print(sales_channel_conversion)

print("\nConversion Rate based on Courier Status:")
print(courier_status_conversion)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9272\1699530682.py:5: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C://Users//User//Documents//Projects//Data Analysis//Finance//Amazon Sale Report.csv')
# Conversion Rate based on Sales Channel:
# Courier Status  Cancelled   Pending  Pending - Waiting for Pick Up   Shipped  \
# Sales Channel
# Amazon.in        0.142265  0.005107                       0.002181  0.602937
# Non-Amazon       0.008065       NaN                            NaN  0.927419
#
# Courier Status  Shipped - Damaged  Shipped - Delivered to Buyer  \
# Sales Channel
# Amazon.in                0.000008                      0.223273
# Non-Amazon                    NaN                           NaN
#
# Courier Status  Shipped - Lost in Transit  Shipped - Out for Delivery  \
# Sales Channel
# Amazon.in                        0.000039                    0.000272
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset (.csv file)
df = pd.read_csv('C://Users//User//Documents//Projects//Data Analysis//Finance//Amazon Sale Report.csv')

# Calculate conversion rate based on Sales Channel
sales_channel_conversion = df.groupby('Sales Channel ')['Courier Status'].value_counts(normalize=True).unstack()

# Calculate conversion rate based on Courier Status
courier_status_conversion = df.groupby('Courier Status')['Sales Channel '].value_counts(normalize=True).unstack()

# Visualization for Conversion Rate based on Sales Channel
plt.figure(figsize=(12, 6))
sns.heatmap(sales_channel_conversion, annot=True, cmap='coolwarm', fmt=".2%")
plt.title('Conversion Rate based on Sales Channel')
plt.show()

# Visualization for Conversion Rate based on Courier Status
plt.figure(figsize=(12, 6))
sns.heatmap(courier_status_conversion, annot=True, cmap='coolwarm', fmt=".2%")
plt.title('Conversion Rate based on Courier Status')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9272\2609866933.py:6: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C://Users//User//Documents//Projects//Data Analysis//Finance//Amazon Sale Report.csv')

# %%
# df is DataFrame
total_revenue = df['Amount'].sum()
total_orders = df['Qty'].count()

average_order_value = total_revenue / total_orders
print(f"Average Order Value: {average_order_value}")
# Out:
# Average Order Value: 609.3636619499902

# %%
import matplotlib.pyplot as plt

# DataFrame df with 'Date' and 'Amount' columns


# Group by date and calculate average order value
average_order_value = df.groupby('Date')['Amount'].mean()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(average_order_value.index, average_order_value.values, marker='o', linestyle='-')
plt.title('Average Order Value Over Time')
plt.xlabel('Date')
plt.ylabel('Average Order Value')
plt.grid(True)
plt.show()

# %%
import pandas as pd

# Assume a DataFrame df with 'Date' and 'Amount' columns


# Group by date and calculate average order value
average_order_value = df.groupby('Date')['Amount'].mean().reset_index()

# Display the DataFrame
print(average_order_value)
# Out:
#          Date      Amount
# 0   3/31/2022  627.678086
# 1    4/1/2022  635.446843
# 2   4/10/2022  642.698165
# 3   4/11/2022  650.383062
# 4   4/12/2022  649.958996
# ..        ...         ...
# 86   6/5/2022  660.716787
# 87   6/6/2022  660.633562
# 88   6/7/2022  666.361118
# 89   6/8/2022  651.026359
# 90   6/9/2022  653.839870
#
# [91 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming the DataFrame is named df and a column 'promotion-ids' is related to promotions


# Filter data for promotion periods
promotion_data = df[df['promotion-ids'].notnull()]

# Calculate total sales during promotion and non-promotion periods
total_sales_promotion = promotion_data['Amount'].sum()
total_sales_non_promotion = df['Amount'].sum() - total_sales_promotion

# Visualize the distribution
labels = ['Promotion', 'Non-Promotion']
values = [total_sales_promotion, total_sales_non_promotion]

plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Sales during Promotion and Non-Promotion Periods')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming the DataFrame is 'df' with columns like 'Category', 'Quantity', 'Amount', etc.

# Size Analysis
plt.figure(figsize=(12, 6))

# Item Quantity Distribution
plt.subplot(1, 2, 1)
sns.histplot(df['Qty'], bins=20, kde=True)
plt.title('Item Quantity Distribution')

# Order Amount Distribution
plt.subplot(1, 2, 2)
sns.boxplot(x='Amount', data=df)
plt.title('Order Amount Distribution')

plt.show()

# Category Analysis
plt.figure(figsize=(12, 8))

# Category-wise Sales
plt.subplot(2, 2, 1)
df_category_sales = df.groupby('Category')['Qty'].sum().sort_values(ascending=False)
df_category_sales.plot(kind='bar', color='skyblue')
plt.title('Category-wise Sales')

# Popular Categories
plt.subplot(2, 2, 2)
df_popular_categories = df['Category'].value_counts().nlargest(5)
df_popular_categories.plot(kind='bar', color='lightcoral')
plt.title('Top 5 Popular Categories')

# Category Distribution
plt.subplot(2, 2, 3)
sns.countplot(x='Category', data=df, palette='viridis')
plt.title('Category Distribution')

# Average Order Value per Category
plt.subplot(2, 2, 4)
df_avg_order_per_category = df.groupby('Category')['Amount'].mean().sort_values(ascending=False)
df_avg_order_per_category.plot(kind='bar', color='salmon')
plt.title('Average Order Value per Category')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9272\2424196887.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Category', data=df, palette='viridis')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming the DataFrame is named 'df'
plt.figure(figsize=(10, 6))
sns.barplot(x='Courier Status', y='Qty', data=df)
plt.title('Courier Status vs Quantity')
plt.xlabel('Courier Status')
plt.ylabel('Quantity')
plt.show()

# %%
import pandas as pd

# Assuming your DataFrame is named 'df'
courier_quantity_table = df.groupby('Courier Status')['Qty'].agg(['mean', 'median', 'std']).reset_index()

# Display the table
print(courier_quantity_table)
# Out:
#                    Courier Status      mean  median       std
# 0                       Cancelled  0.308586     0.0  0.464983
# 1                         Pending  0.998480     1.0  0.067557
# 2   Pending - Waiting for Pick Up  1.007117     1.0  0.084214
# 3                         Shipped  1.002635     1.0  0.105530
# 4               Shipped - Damaged  1.000000     1.0       NaN
# 5    Shipped - Delivered to Buyer  1.004067     1.0  0.081806
# 6       Shipped - Lost in Transit  1.000000     1.0  0.000000
# 7      Shipped - Out for Delivery  1.000000     1.0  0.000000
# 8             Shipped - Picked Up  1.004111     1.0  0.064018
# 9     Shipped - Rejected by Buyer  1.000000     1.0  0.000000
# 10   Shipped - Returned to Seller  1.008705     1.0  0.144666
# 11  Shipped - Returning to Seller  1.034483     1.0  0.183098
# 12                       Shipping  1.000000     1.0  0.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
currency_amount_analysis = df.groupby('currency')['Amount'].sum().reset_index()

# Display a bar chart to visualize the total amount for each currency
plt.figure(figsize=(10, 6))
plt.bar(currency_amount_analysis['currency'], currency_amount_analysis['Amount'])
plt.xlabel('Currency')
plt.ylabel('Total Amount')
plt.title('Currency and Amount Analysis')
plt.show()

# %%
import pandas as pd
df.to_csv('Amazon Python Results.csv', index=False)

# %%
import pandas as pd

# DataFrame named 'df' containing results of the analysis
df.to_csv('Amazon Python Results.csv', index=False)

# To create a download link:
from IPython.display import FileLink

FileLink('Amazon Python Results.csv')
# Out:
# c:\Users\User\Desktop\Amazon Python Results.csv

# %%
#Extract Day Of The Week
import pandas as pd
df['Date'] = pd.to_datetime(df['Date'])
df['DayOfWeek'] = df['Date'].dt.day_name()

# %%
#Creating Categorical Variables
df_encoded = pd.get_dummies(df,columns=['Sales Channel '],prefix='Sales Channel ')

# %%
#Creating Interaction Terms With Quantity & Amount
df['InteractionTerm'] = df['Qty'] * df['Amount']

# %%
#To Handle Missing Data
df.dropna(inplace=True)

# %%
# Assuming 'df' is your DataFrame
# Selecting features and target
features = df[['Category', 'Date', 'Amount']]
target = df['Qty']

# Print shapes
print("Features shape:", features.shape)
print("Target shape:", target.shape)
# Out:
# Features shape: (19379, 3)
# Target shape: (19379,)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22', 'DayOfWeek', 'InteractionTerm'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# Assuming your DataFrame is named 'df'
features = df[['Category', 'Date', 'Amount']]
target = df['Qty']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Print shapes of the training and testing sets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (15503, 3)
# X_test shape: (3876, 3)
# y_train shape: (15503,)
# y_test shape: (3876,)

# %%
#Choosing A Model
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split

# Where df is the DataFrame
features = df[['Category', 'Date', 'Amount', 'Sales Channel ']]
target = df['Qty']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
X_train_encoded = pd.get_dummies(X_train, columns=['Category', 'Sales Channel '])
X_test_encoded = pd.get_dummies(X_test, columns=['Category', 'Sales Channel '])

# %%
#df is the DataFrame
df['Date'] = (df['Date'] - df['Date'].min()).dt.days


features = df[['Category', 'Date', 'Amount', 'Sales Channel ']]
target = df['Qty']

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Performing one-hot encoding
X_train_encoded = pd.get_dummies(X_train, columns=['Category', 'Sales Channel '])
X_test_encoded = pd.get_dummies(X_test, columns=['Category', 'Sales Channel '])

# Train model
model.fit(X_train_encoded, y_train)
# Out:
# LinearRegression()

# %%
# Making Predictions On The Test Set

from sklearn.metrics import mean_squared_error, r2_score

predictions = model.predict(X_test_encoded)

# Evaluating the model
mse = mean_squared_error(y_test, predictions)
r_squared = r2_score(y_test, predictions)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r_squared}')
# Out:
# Mean Squared Error: 0.006132053947563895
# R-squared: 0.04406769560825663

# %%
import matplotlib.pyplot as plt

# Assuming these are placeholder values, replace them with your actual data
actual_quantity = [10, 15, 20]
predicted_quantity = [12, 14, 18]

# Visualization
plt.scatter(range(len(actual_quantity)), actual_quantity, color='blue', label='Actual Quantity')
plt.scatter(range(len(predicted_quantity)), predicted_quantity, color='red', label='Predicted Quantity')
plt.xlabel('Data Point')
plt.ylabel('Quty')
plt.title('Actual vs. Predicted Quantity')
plt.legend()
plt.show()

# %%
import joblib
joblib.dump(model, 'Amazon_model.pkl')
# Out:
# ['Amazon_model.pkl']

# %%
{
  "features": {
    "Sales Channel ": "some_channel",
    "Amount": 123.45
  }
}
# Out:
# {'features': {'Sales Channel ': 'some_channel', 'Amount': 123.45}}

# %%
from flask import Flask, request, jsonify
import joblib

app = Flask(__name__)

# Replace the path below with the direct path to your model (Amazon_Model.pkl)
model_path = "C:/Users/User/Desktop/Amazon_Model.pkl"
model = joblib.load(model_path)

@app.route('/predict', methods=['POST'])
def predict():
    data = request.get_json(force=True)
    prediction = model.predict(data['features'])
    return jsonify(prediction.tolist())

if __name__ == '__main__':
    app.run(port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
